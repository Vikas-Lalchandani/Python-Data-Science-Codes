# %%
import pandas as pd

# %%
#Creating Series using Pandas - 1 Dimensional object
car_brand = pd.Series(["KIA","HONDA","SUZUKI"])
car_brand
# Out:
# 0       KIA
# 1     HONDA
# 2    SUZUKI
# dtype: object

# %%
#Creating Series using Pandas - 1 Dimensional object
car_color = pd.Series(["Grey","Maroon","Blue"])
car_color
# Out:
# 0      Grey
# 1    Maroon
# 2      Blue
# dtype: object

# %%
#Creating Dataframe using Series
cars = pd.DataFrame({"Brand" : car_brand, "Color" : car_color})

# %%
cars
# Out:
#     Brand   Color
# 0     KIA    Grey
# 1   HONDA  Maroon
# 2  SUZUKI    Blue

# %%
car_sales = pd.read_csv("car_sales.csv")

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# #### Describing Data

# %%
#to check for attributes
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
animals = pd.Series(["tiger", "cat", "dog", "elephant", "panda"],
                   index = [0,3,4,8,9])

# %%
animals_new = pd.Series(["tiger", "cat", "dog", "elephant", "panda"],
                   index = ["a","b","c","a","d"])

# %%
animals
# Out:
# 0       tiger
# 3         cat
# 4         dog
# 8    elephant
# 9       panda
# dtype: object

# %%
#.loc gets the value based on index number/name

animals.loc[3]
# Out:
# 'cat'

# %%
animals_new.loc["a"]
# Out:
# a       tiger
# a    elephant
# dtype: object

# %%
#iloc gives the value based on actual index position
animals.iloc[3]
# Out:
# 'elephant'

# %%
animals_new.iloc[4]
# Out:
# 'panda'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[:7]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.iloc[:7]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Groupby
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(['Make'])[['Odometer (KM)','Doors']].mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,]','').astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales.groupby(['Make'])[['Odometer (KM)','Doors','Price']].mean()
# Out:
#         Odometer (KM)  Doors    Price
# Make
# BMW      11179.000000   5.00  22000.0
# Honda    62778.333333   4.00   6500.0
# Nissan  122347.500000   4.00   6600.0
# Toyota   85451.250000   3.75   5437.5

# %% [markdown]
# ### Manipulating Data

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car_sales_missing_values.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.fillna(car_sales_missing["Odometer"].mean())
# Out:
#       Make   Colour       Odometer         Doors    Price
# 0   Toyota    White  150043.000000      4.000000   $4,000
# 1    Honda      Red   87899.000000      4.000000   $5,000
# 2   Toyota     Blue   92302.666667      3.000000   $7,000
# 3      BMW    Black   11179.000000      5.000000  $22,000
# 4   Nissan    White  213095.000000      4.000000   $3,500
# 5   Toyota    Green   92302.666667      4.000000   $4,500
# 6    Honda  92302.7   92302.666667      4.000000   $7,500
# 7    Honda     Blue   92302.666667      4.000000  92302.7
# 8   Toyota    White   60000.000000  92302.666667  92302.7
# 9  92302.7    White   31600.000000      4.000000   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_seats = pd.Series([5,5,5,5,5,5])

# %%
car_seats
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
car_sales["Seats"] = car_seats

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
Fuels = [7.5, 9.5, 4, 7.8, 8.2, 6, 3.5, 5.5, 7.2, 9]

# %%
car_sales["Fuel per 100KM"] = Fuels

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.5
# 2  toyota   Blue          32549      3   7000.0    5.0             4.0
# 3     bmw  Black          11179      5  22000.0    5.0             7.8
# 4  nissan  White         213095      4   3500.0    5.0             8.2
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 6   honda   Blue          45698      4   7500.0    5.0             3.5
# 7   honda   Blue          54738      4   7000.0    5.0             5.5
# 8  toyota  White          60000      4   6250.0    5.0             7.2
# 9  nissan  White          31600      4   9700.0    5.0             9.0

# %%
car_sales["Total Fuel Used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.5
# 2  toyota   Blue          32549      3   7000.0    5.0             4.0
# 3     bmw  Black          11179      5  22000.0    5.0             7.8
# 4  nissan  White         213095      4   3500.0    5.0             8.2
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 6   honda   Blue          45698      4   7500.0    5.0             3.5
# 7   honda   Blue          54738      4   7000.0    5.0             5.5
# 8  toyota  White          60000      4   6250.0    5.0             7.2
# 9  nissan  White          31600      4   9700.0    5.0             9.0
#
#    Total Fuel Used  Total Fuel Used (L)
# 0        11253.225            11253.225
# 1         8350.405             8350.405
# 2         1301.960             1301.960
# ...

# %%
car_sales["Total Fuel Used (L)"] = car_sales["Total Fuel Used"]

# %%
car_sales["Number of Wheels"] = 4

# %%
car_sales["Passed Road Safety"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.5
# 2  toyota   Blue          32549      3   7000.0    5.0             4.0
# 3     bmw  Black          11179      5  22000.0    5.0             7.8
# 4  nissan  White         213095      4   3500.0    5.0             8.2
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 6   honda   Blue          45698      4   7500.0    5.0             3.5
# 7   honda   Blue          54738      4   7000.0    5.0             5.5
# 8  toyota  White          60000      4   6250.0    5.0             7.2
# 9  nissan  White          31600      4   9700.0    5.0             9.0
#
#    Total Fuel Used  Total Fuel Used (L)  Number of Wheels  Passed Road Safety
# 0        11253.225            11253.225                 4                True
# ...

# %%
car_sales.drop("Total Fuel Used", axis = 1, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.5
# 2  toyota   Blue          32549      3   7000.0    5.0             4.0
# 3     bmw  Black          11179      5  22000.0    5.0             7.8
# 4  nissan  White         213095      4   3500.0    5.0             8.2
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 6   honda   Blue          45698      4   7500.0    5.0             3.5
# 7   honda   Blue          54738      4   7000.0    5.0             5.5
# 8  toyota  White          60000      4   6250.0    5.0             7.2
# 9  nissan  White          31600      4   9700.0    5.0             9.0
#
#    Total Fuel Used (L)  Number of Wheels  Passed Road Safety
# 0            11253.225                 4                True
# 1             8350.405                 4                True
# ...

# %%
#To get fraction of dataframe
car_sales.sample(frac = 0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 3     bmw  Black          11179      5  22000.0    5.0             7.8
# 1   honda    Red          87899      4   5000.0    5.0             9.5
# 4  nissan  White         213095      4   3500.0    5.0             8.2
# 6   honda   Blue          45698      4   7500.0    5.0             3.5
#
#    Total Fuel Used (L)  Number of Wheels  Passed Road Safety
# 5             5952.780                 4                True
# 3              871.962                 4                True
# 1             8350.405                 4                True
# 4            17473.790                 4                True
# 6             1599.430                 4                True

# %%
car_sales_shuffled = car_sales.sample(frac = 1)

# %%
car_sales_shuffled.reset_index(drop = True, inplace = True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  nissan  White         213095      4   3500.0    5.0             8.2
# 1  nissan  White          31600      4   9700.0    5.0             9.0
# 2     bmw  Black          11179      5  22000.0    5.0             7.8
# 3  toyota  Green          99213      4   4500.0    5.0             6.0
# 4  toyota  White          60000      4   6250.0    5.0             7.2
# 5   honda   Blue          45698      4   7500.0    5.0             3.5
# 6   honda    Red          87899      4   5000.0    5.0             9.5
# 7  toyota   Blue          32549      3   7000.0    5.0             4.0
# 8   honda   Blue          54738      4   7000.0    5.0             5.5
# 9  toyota  White         150043      4   4000.0    5.0             7.5
#
#    Total Fuel Used (L)  Number of Wheels  Passed Road Safety
# 0            17473.790                 4                True
# 1             2844.000                 4                True
# ...

# %%
car_sales["Odometer (Miles)"] = car_sales["Odometer (KM)"].apply(lambda x : x/1.61)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.5
# 2  toyota   Blue          32549      3   7000.0    5.0             4.0
# 3     bmw  Black          11179      5  22000.0    5.0             7.8
# 4  nissan  White         213095      4   3500.0    5.0             8.2
# 5  toyota  Green          99213      4   4500.0    5.0             6.0
# 6   honda   Blue          45698      4   7500.0    5.0             3.5
# 7   honda   Blue          54738      4   7000.0    5.0             5.5
# 8  toyota  White          60000      4   6250.0    5.0             7.2
# 9  nissan  White          31600      4   9700.0    5.0             9.0
#
#    Total Fuel Used (L)  Number of Wheels  Passed Road Safety  Odometer (Miles)
# 0            11253.225                 4                True      93194.409938
# ...
